# %% [markdown]
# ## Mini project [행맨 게임 제작]
#
# 안녕하세요.
# 수강생 여러분~! Chapter 1 ~ 6 까지의 수업은 잘 들으셨나요?
#
# 여러분의 모든 역량을 총 동원해 문제를 풀어주셨합니다.
#
#
#
# #### 과제 설명
#
# 이번 개발 주제는 '행맨' 게임이구요.
#
# 행맨 게임은 아주 유명한 단어 퀴즈 프로그램이예요
#
# 어떤 단어가 주어지면 그 단어의 길이만큼 빈 칸(밑줄) 이 주어지고
# 플레이어는 알파벳을 하나씩 얘기하면서 단어를 추측해요!
#
# 10번만에 맞히지 못하면 게임이 끝납니다. 🥲

# %% [markdown]
# #### 예시를 들어볼께요!!
#
# 만약 E 가 단어에 포함돼있다면, 해당하는 위치에 E 를 표시해줍니다
#
# _ _ _ _ E E
# 이렇게 되겠네요.
#
# 이번에는 A를 해볼께요
# A 는 포함되지 않으므로 기회가 줄어들고 지금까지 맞힌 내용 그대로 출력합니다.
#
# _ _ _ _ E E
# 변화가 없지요.
#
# 이번에는 C 를 해봅시다.
#
# 그럼
# C _ _ _ E E
#
# 다음에는 F 를
# C _ F F E E
#
# 마지막으로 O 를 해보면
# C O F F E E 로 게임은 성공으로 끝나게 됩니다.

# %% [markdown]
# ##본격적인 행맨 게임 규칙 설명
#
# - words 리스트에 추가된 단어들을 사용해주세요
#   - words = ["apple", "banana", "orange", "grape", "lemon"]
#
# - 단어의 길이에 맞게 밑줄을 출력해주세요
#   (예)banana의 경우 _ _ _ _ _ _
#
# - 사용자부터 1글자씩 입력을 받되,
#    - 단어에 입력값이 포함되면 "단어를 맞추셨군요. 더 힘내봐요"라고 출력해주세요"
#    - 단어에 입력값이 포함되어 있지 않다면 "틀렸습니다. 남은 시도 횟수 "란 메시지와 함꼐 남은 횟수를 출력해주세요
#
# - 매번 입력을 받을 때마다 현재까지 맞힌 글자들 표시(맞히면 글자는 밑줄 출력)
#     - 예) a 입력 시 : a _ _ _ _
#           p 입력 시 : a p p _ _
#           c 입력 시 : a p p _ _
#
# - 모든 단어를 맞췄을 경우 "축하합니다! 단어를 맞추셨습니다"와 시도 횟수를 출력해주세요
#
#
# 행맨은 정말 유명 게임으로 찾아볼 수 있는 자료들이 많습니다.
# 문제가 어려우신 경우 구글링 통해 문제를 해결해보세요.

# %%
시퀀스
1. 문제 출제 (주어진것 중 랜덤하게 선택)
2. 문제로 선택된 문자의 길이 확인
3. 문자의 길이만큼 _ 생성 + 행맨[0] 생성
4. 유저 단어 입력 (1글자씩)
 4-1. 맞으면 : 기회가 줄어들진 않나? // _ 대신에 맞춘 글자 대체하기 (기회 카운트)
 4-2. 틀리면 : 기회가 줄어듦 // 문제 그대로 출력 (기회 카운트) // 행맨 다음 그림으로 
5. 남은 기회 확인 ?
 5-1. 주어진 기회안에 정답을 맞추면 // 따봉 그림 // n 번째만에 성공했어요! 출력     
 5-2. 기회를 모두 날리면 : 끝
 5-3. 기회가 아직 남았다면 계속 진행

# %%
# <테스트코드>
# 알고리즘문제 - 작성과정을 기록으로 남기기 위함 **

# 기본 라이브러리라 파이썬 설치시 자동으로 설치됩니다!
# random 모듈은 랜덤한 숫자를 생성할 때 사용합니다.

import random

# 행맨 그림
hangman_pics = [
    """
     ------
     |    |
     |
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |    |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   /
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   / \
     |
    ---""",
]

win_art = """
   _
 ( ((
  \\ =\\
 __\\_ `-\\ 
(____))(  \\----
(____)) _  
(____))
(____))____/----
"""

# quiz : 
# question : 

class HangmanGame:
    def __init__(self):
        self.life_count = 6 # 목숨
        self.chance_count = 0 # 기회횟수
        self.question = "" # 문제 // 단어 사이 "언더바" 추가해야함
        #self.words = ["apple" , "banana", "orange", "grape", "lemon"] # 게임에 사용될 단어 목록
        self.words = ["apple"] # 게임에 사용될 단어 목록
        self.correct_answer = "" # 입력된 단어가 정답일 경우 합체
        self.all_answer = list()
        
    def play(self):
        # 1. 문제출제
        quiz_word = random.choice(self.words) # words의 단어 중 랜덤하게 선택 됨
        print(f'선택된 문제 : {quiz_word}')  # 선택된 문제 출력 // 확인용
        quiz_idx = list()   # quiz 변수의 인덱스를 리스트로 선언    // 왜 선언했지??????

        # 2. 문제로 선택된 단어의 길이 확인
        # 퀴즈로 선택된 단어의 길이만큼 _(언더바) 생성 // 언더바 사이 공백 필요 // _ _ _ _ _ ...
        self.question = " ".join("_" * len(quiz_word))

        # 3. 언더바 및 행맨 출력
          # 3-1. 문자의 길이 만큼 언더바 출력
        print(self.question)
          
          # 3-2. 행맨 출력
        print(hangman_pics[self.chance_count]) # 남은 기회에 따라 이미지 상이함 // 문제를 틀릴 때 마다 idx+1 or idx-1 구조로 작성 필요함!!!!!
        
# ------------------------------------------------------------------------------------ 여기서부터 반복문 돌리기
        # [해결해야할것들]
        # 1. 중복단어 있을 때 // 예로 banana의 a
        # 2. 유저가 한글자 이상 입력할때? => 두글자 이상 입력될 때 다시 입력하라고 하기

        while self.life_count > 0: # 목숨이 0개 이상일때까지 정답을 입력할 수 있는 기회를 줌
            # 4. 유저 단어 입력 (1글자씩)
            input_word = input("정답을 한 글자씩 입력해주세요! (end(0)를 입력하면 종료됩니다.)") # 유저가 정답을 직접 입력

            if input_word == "end" or input_word == "0":
                print("게임이 곧 종료됩니다.")
                break

            # 예외처리2) 두 글자 이상 입력할 때 처리
            if len(input_word) > 1:
                print(f'한 글자 이상이 입력되었습니다. 다시 입력해주세요!')
                continue

            # 정답과 비교
            #  4-1. 맞으면 : 기회가 줄어들진 않나? // _ 대신에 맞춘 글자 대체하기 (기회 카운트)
            if input_word in quiz_word: # 정답단어(quiz_word)에 유저가 입력한 단어(input_word)가 있다면
                list_question = list(self.question)
                for idx, quiz_word_txt in enumerate(quiz_word): # 비교를 위해 정답의 단어와 인덱스를 할당
                    if input_word == quiz_word_txt: # 만약 단어가 일치한다면
                        list_question[idx*2] = input_word # 언더바를 정답단어로 변경 // 인덱스에 *2를 한 이유 : 언더바 구분을 위해 언더바간 공백이 있음 (공백도 문자열로 취급되기때문)
                        self.question = "".join(list_question)
                        self.all_answer.append(input_word)
                        print(f'현재 맞춘 글자들 : {self.all_answer} 남은 기회는 {self.life_count} 회입니다!')
                print(f"{self.question} 단어를 맞추셨군요. 좀 더 힘내봐요!!")           
                print(hangman_pics[self.chance_count])              

            #  4-2. 틀리면 : 기회가 줄어듦 // 문제 그대로 출력 (기회 카운트) // 행맨 다음 그림으로   
            else:    # 정답단어(quiz_word)에 유저가 입력한 단어(answer_word)가 없다면
                self.life_count -= 1 # 목숨 1개 감소
                self.chance_count += 1 # 기회 1개 증가
                print(f"{self.question} 틀렸습니다. 남은 기회는 {self.life_count} 회입니다!")
                print(hangman_pics[self.chance_count]) # 행맨이미지 업데이트


            # 5. 남은 기회 확인 and 전체 정답 확인
                #  5-1. 주어진 기회안에 정답을 맞추면 // 따봉 그림 // n 번째만에 성공했어요! 출력     
            # 여기서 전체 정답 확인 필요 (조건문)
            if set(quiz_word) == set(self.all_answer):
                print("축하합니다. 단어를 모두 맞추셨습니다!")
                print(win_art)
                return 

            #  5-2. 기회를 모두 날리면 : 끝 => 반복문 끝나면 출력
        # 기회안에 정답 못 맞출 경우 (조건문?)
        print(f'GAME OVER')
        print(f'정답은 {quiz_word} 입니다.') 

if __name__ == "__main__":
    game = HangmanGame()
    game.play()


# 시퀀스
# 1. 문제 출제 (주어진것 중 랜덤하게 선택)
# 2. 문제로 선택된 문자의 길이 확인
# 3. 문자의 길이만큼 _ 생성 + 행맨[0] 생성
# 4. 유저 단어 입력 (1글자씩)
#  4-1. 맞으면 : 기회가 줄어들진 않나? // _ 대신에 맞춘 글자 대체하기 (기회 카운트)
#  4-2. 틀리면 : 기회가 줄어듦 // 문제 그대로 출력 (기회 카운트) // 행맨 다음 그림으로 
# 5. 남은 기회 확인 ?
#  5-1. 주어진 기회안에 정답을 맞추면 // 따봉 그림 // n 번째만에 성공했어요! 출력     
#  5-2. 기회를 모두 날리면 : 끝
#  5-3. 기회가 아직 남았다면 계속 진행

# %%
# print("____")


# a = "aaaa"
# print(' '.join(a))

# a = "banana"
# word = "n"
# print(a.find(word))

# print(a.replace(a.find(word), word))


# quiz = "banana"
# word = "n"
# quiz_idx = list()

# for i, quiz_word in enumerate(quiz):
#     if word in quiz_word:
#         print(i, quiz_word)
#         quiz_idx.append(i)



# #### 공백 추가 문자의 인덱스
# aa = "abcdefg"
# bb = '_'.join(aa)

# print(aa)
# print(bb)

# print(aa[1])
# print(bb[1])

## 단어 위치 출력
aa = "abcdefgcd"
word = "c"

# if word in aa:
#     print(aa.index(word))



# for i in range(aa.count(word)):

# aaa = list(aa)
# aaa.reverse()
# aaa.remove("c")
# aaa.reverse()
# aj = ''.join(aaa)

# print(aj)

# aj = ''.join(aaa)


# print(aaa)
# print(aj)

al = ["a", "p", "p", "l", "e"]
ad = ["a", "p", "p", "l", "e"]
ar = ["e", "p", "p", "l", "a"]
ac = ["a", "p", "p", "l"]

al.sort()
print(al)

print(set(al) == set(ad))
print(set(al) == set(ac))
print(set(al) == set(ar))



print(" ".join("_"*6))
# Out:
# ['a', 'e', 'l', 'p', 'p']
# True
# False
# True
# _ _ _ _ _ _

# %%
# <완성코드>

import random

# 행맨 그림
hangman_pics = [
    """
     ------
     |    |
     |
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |    |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   /
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   / \
     |
    ---""",
]

win_art = """
   _
 ( ((
  \\ =\\
 __\\_ `-\\ 
(____))(  \\----
(____)) _  
(____))
(____))____/----
"""

class HangmanGame:
    def __init__(self):
        self.life_count = 6 # 목숨
        self.chance_count = 0 # 기회횟수
        self.question = "" # 문제 // 단어 사이 "언더바" 추가해야함
        self.words = ["apple" , "banana", "orange", "grape", "lemon"] # 게임에 사용될 단어 목록
        self.correct_answer = "" # 입력된 단어가 정답일 경우 합체
        self.all_answer = list()
        
    def play(self):
        # 1. 문제출제
        quiz_word = random.choice(self.words) # words의 단어 중 랜덤하게 선택 됨
        print(f'선택된 문제 : {quiz_word}')  # 선택된 문제 출력 // 확인용

        # 2. 문제로 선택된 단어의 길이 확인
        # 퀴즈로 선택된 단어의 길이만큼 _(언더바) 생성 // 언더바 사이 공백 필요 // _ _ _ _ _ ...
        self.question = " ".join("_" * len(quiz_word))

        # 3. 언더바 및 행맨 출력
        print(self.question)
        print(hangman_pics[self.chance_count])
        
        while self.life_count > 0: # 목숨이 0개 이상일때까지 정답을 입력할 수 있는 기회를 줌
            # 4. 유저 단어 입력 (1글자씩)
            input_word = input("정답을 한 글자씩 입력해주세요! (end(0)를 입력하면 종료됩니다.)") # 유저가 정답을 직접 입력

            if input_word == "end" or input_word == "0": # end 혹은 0 입력 시 게임 종료됨
                print("게임이 곧 종료됩니다.")
                break 

            # 예외처리2) 두 글자 이상 입력할 때 처리
            if len(input_word) > 1:
                print(f'한 글자 이상이 입력되었습니다. 다시 입력해주세요!')
                continue

            # 이미 맞춘 글자를 또 입력하면
            if input_word in self.all_answer:
                print(f'이미 맞춘 글자입니다. 다시 입력해주세요!')
                continue

            # 정답과 비교
            #  4-1. 맞추면
            if input_word in quiz_word: # 정답단어(quiz_word)에 유저가 입력한 단어(input_word)가 있다면
                list_question = list(self.question)
                for idx, quiz_word_txt in enumerate(quiz_word): # 비교를 위해 정답의 단어와 인덱스를 할당
                    if input_word == quiz_word_txt: # 만약 단어가 일치한다면
                        list_question[idx*2] = input_word # 언더바를 정답단어로 변경
                        self.question = "".join(list_question)
                        self.all_answer.append(input_word)
                        print(f'현재 맞춘 글자들 : {self.all_answer} 남은 기회는 {self.life_count} 회입니다!')
                print(f"{self.question} 단어를 맞추셨군요. 좀 더 힘내봐요!!")           
                print(hangman_pics[self.chance_count])             
            #  4-2. 틀리면   
            else:
                self.life_count -= 1 # 목숨 1개 감소
                self.chance_count += 1 # 기회 1개 증가
                print(f"{self.question} 틀렸습니다. 남은 기회는 {self.life_count} 회입니다!")
                print(hangman_pics[self.chance_count]) # 행맨이미지 업데이트

            # 5. 남은 기회 확인 and 전체 정답 확인
                #  5-1. 주어진 기회안에 정답을 맞추면 // 따봉 그림 // n 번째만에 성공했어요! 출력     
            if set(quiz_word) == set(self.all_answer):
                print("축하합니다. 단어를 모두 맞추셨습니다!")
                print(win_art)
                return 

            #  5-2. 기회를 모두 날리면
        print(f'GAME OVER')
        print(f'정답은 {quiz_word} 입니다.') 

if __name__ == "__main__":
    game = HangmanGame()
    game.play()
# Out:
# 선택된 문제 : lemon
# _ _ _ _ _
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재 맞춘 글자들 : ['l'] 남은 기회는 6 회입니다!
# l _ _ _ _ 단어를 맞추셨군요. 좀 더 힘내봐요!!
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 이미 맞춘 글자입니다. 다시 입력해주세요!
# 이미 맞춘 글자입니다. 다시 입력해주세요!
# 현재 맞춘 글자들 : ['l', 'e'] 남은 기회는 6 회입니다!
# l e _ _ _ 단어를 맞추셨군요. 좀 더 힘내봐요!!
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# l e _ _ _ 틀렸습니다. 남은 기회는 5 회입니다!
#
#      ------
#      |    |
#      |    O
#      |
#      |
#      |
#     ---
# 현재 맞춘 글자들 : ['l', 'e', 'm'] 남은 기회는 5 회입니다!
# l e m _ _ 단어를 맞추셨군요. 좀 더 힘내봐요!!
#
#      ------
#      |    |
#      |    O
#      |
#      |
#      |
#     ---
# 현재 맞춘 글자들 : ['l', 'e', 'm', 'o'] 남은 기회는 5 회입니다!
# l e m o _ 단어를 맞추셨군요. 좀 더 힘내봐요!!
#
#      ------
#      |    |
#      |    O
#      |
#      |
#      |
#     ---
# 이미 맞춘 글자입니다. 다시 입력해주세요!
# l e m o _ 틀렸습니다. 남은 기회는 4 회입니다!
#
#      ------
#      |    |
#      |    O
# ...
