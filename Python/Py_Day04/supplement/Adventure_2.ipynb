# %% [markdown]
# # 숲 속의 시련 🌳
# > ## 숲에 들어서자 다양한 도전이 기다리고 있습니다. 숲을 탈출하기 위해 더 복잡한 문제들을 해결해야 합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [문제 1] **"숲 속의 물웅덩이"**
# ### 물웅덩이를 건너기 위해 평균을 계산하세요.
# ### 물웅덩이 너비는 각각 3m, 7m, 5m 입니다. 이들의 평균을 계산하세요.
# > ### 사용할 변수명 : `average`

# %% [markdown]
# # [문제 2] **"마법의 돌"**
# ### 마법의 돌은 짝수일 때만 반응합니다.
# ### 사용자로부터 숫자를 입력받고, 짝수인지 홀수인지 출력하세요.
# > ### 사용할 함수 : `numbers`

# %% [markdown]
# # [문제 3] **"길을 잃은 마법사"**
# ### 길을 잃은 마법사를 돕기 위해 좌표를 수정해야합니다.
# ### 변수 `x=19`, `y=20`의 값을 서로 바꿔 출력하세요.

# %% [markdown]
# # [문제 4] **"비밀 상자"**
# ### 상자에 적힌 문자를 뒤집어야 상자를 열 수 있습니다.
# ### 변수 text에 `"OpenMe!"`를 저장하고, 이를 뒤집어 출력하세요.
# > ### 사용할 변수명 : `text`

# %% [markdown]
# # [문제 5] **"숲 속의 시계"**
# ### 숲 속에 있는 오래된 시계의 시간을 읽어야 합니다.
# ### 초 단위로 주어진 값 `5000`을 `시:분:초` 형태로 변환하세요.
# > ### 사용할 변수명 : `seconds`, `minutes`, `hours`

# %% [markdown]
# # [문제 6] **"보물의 좌표"**
# ### 보물이 숨겨진 좌표는 특정 숫자들의 곱입니다.
# ### 사용자로부터 두 숫자를 입력받아 곱한 값을 출력하세요.
# > ### 사용할 변수명 : `num1`, `num2`
